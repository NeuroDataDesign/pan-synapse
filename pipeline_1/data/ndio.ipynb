# %%
import ndio.remote.neurodata as neurodata

# %%
nd = neurodata()

# %%
public_tokens = nd.get_public_tokens()

public_tokens
# Out:
# [u'113_1_demo2',
#  u'a153_hs3',
#  u'ac3',
#  u'ac4',
#  u'acardona_0111_8',
#  u'acardona_abd1_5',
#  u'allen_gold_16_000',
#  u'allen_gold_16_001',
#  u'allen_gold_16_002',
#  u'allen_gold_16_003',
#  u'allen_gold_16_004',
#  u'allen_gold_16_005',
#  u'allen_gold_16_006',
#  u'allen_gold_16_007',
#  u'allen_gold_16_008',
#  u'allen_gold_16_009',
#  u'allen_gold_16_010',
#  u'allen_gold_16_011',
#  u'allen_gold_16_012',
#  u'allen_gold_16_013',
#  u'allen_gold_16_014',
#  u'allen_gold_16_015',
#  u'allen_gold_16_016',
#  u'allen_gold_16_017',
#  u'allen_gold_16_018',
#  u'allen_gold_16_019',
#  u'allen_gold_16_020',
#  u'allen_gold_16_021',
#  u'allen_gold_16_022',
#  u'allen_gold_16_023',
#  u'allen_gold_16_024',
#  u'allen_gold_16_025',
#  u'allen_gold_16_026',
#  u'allen_gold_16_027',
#  u'allen_gold_16_028',
#  u'allen_gold_16_029',
#  u'allen_gold_16_030',
#  u'allen_gold_16_031',
#  u'allen_gold_16_032',
#  u'allen_gold_16_033',
#  u'allen_gold_16_034',
# ...

# %%
TOKEN='collman15'
CHANNEL='DAPI1st'

query={
    'token': TOKEN,
    'channel': CHANNEL,
    'x_start': 0,
    'x_stop': 100,
    'y_start': 0,
    'y_stop': 100,
    'z_start': 0,
    'z_stop': 5,
    'resolution': 3
    
}

test = nd.get_cutout(**query)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-13-fb368a8593bb> in <module>()
#      15 }
#      16
# ---> 17 test = nd.get_cutout(**query)
#
# /usr/local/lib/python2.7/dist-packages/ndio/remote/neurodata.pyc in wrapped(self, *args, **kwargs)
#      95                     else:
#      96                         self._known_tokens.append(token)
# ---> 97             return f(self, *args, **kwargs)
#      98         return wrapped
#      99
#
# /usr/local/lib/python2.7/dist-packages/ndio/remote/neurodata.pyc in get_cutout(self, token, channel, x_start, x_stop, y_start, y_stop, z_start, z_stop, resolution, block_size, neariso)
#     551                           x_start, x_stop,
#     552                           y_start, y_stop,
# --> 553                           z_start, z_stop, neariso=neariso)
#     554             vol = numpy.rollaxis(vol, 1)
# ...

# %%
TOKEN='collman14'
CHANNEL='DAPI_2nd'

query={
    'token': TOKEN,
    'channel': CHANNEL,
    'x_start': 0,
    'x_stop': 100,
    'y_start': 0,
    'y_stop': 100,
    'z_start': 0,
    'z_stop': 5,
    'resolution': 3
    
}

test = nd.get_cutout(**query)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-fa7b73e8636a> in <module>()
#      15 }
#      16
# ---> 17 test = nd.get_cutout(**query)
#
# /usr/local/lib/python2.7/dist-packages/ndio/remote/neurodata.pyc in wrapped(self, *args, **kwargs)
#      95                     else:
#      96                         self._known_tokens.append(token)
# ---> 97             return f(self, *args, **kwargs)
#      98         return wrapped
#      99
#
# /usr/local/lib/python2.7/dist-packages/ndio/remote/neurodata.pyc in get_cutout(self, token, channel, x_start, x_stop, y_start, y_stop, z_start, z_stop, resolution, block_size, neariso)
#     551                           x_start, x_stop,
#     552                           y_start, y_stop,
# --> 553                           z_start, z_stop, neariso=neariso)
#     554             vol = numpy.rollaxis(vol, 1)
# ...
